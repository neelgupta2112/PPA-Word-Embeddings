# %% [markdown]
# # PPA Word Embeddings — Test and Visualize Embeddings with Altair
# August 17, 2025
# MW

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm
from itertools import islice
import json
import gzip
import pandas as pd
import re
import altair as alt
import numpy as np
import string
import random
import umap

# %% [markdown]
# # Extract contextual embeddings for each word/token
#
# Define function to extract contextual embeddings for each word/token

# %% [markdown]
# MW note: With the previous code, we were including punctuation at the end of tokens, like "ballad." or "ballad,". I made an adjust that should fix it.

# %%
def extract_usage_representations(text, tokenizer, model, device="cpu", skip_stopwords=True):
    encoded = tokenizer(
        text,
        return_tensors="pt",
        return_offsets_mapping=True,
        truncation=True
    )
    
    input_ids = encoded["input_ids"].to(device)
    attention_mask = encoded["attention_mask"].to(device)
    offsets = encoded["offset_mapping"][0]

    with torch.no_grad():
        output = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            output_hidden_states=True
        )
        hidden_states = output.hidden_states  # (layers, batch, seq_len, hidden_size)

    all_layers = torch.stack(hidden_states, dim=0)  # (layers, batch, seq_len, hidden)
    summed = all_layers.sum(dim=0)[0]  # (seq_len, hidden_size)

    tokens = tokenizer.convert_ids_to_tokens(input_ids[0])
    special_tokens = set(tokenizer.all_special_tokens)

    usage_vectors = []
    current_word = ""
    current_vecs = []
    current_start = None
    current_end = None

    STOPWORDS = {
       "the", "and", "for", "but", "with", "that", "this", "from", "not",
      "you", "are", "was", "were", "have", "has", "had", "she", "he", "they",
       "his", "her", "its", "our", "their", "will", "would", "can", "could"
    }

    for i, token in enumerate(tokens):
        # skip special tokens
        if token in special_tokens:
            continue

        # detect new word
        is_new_word = token.startswith("Ġ") or i == 0

        if is_new_word and current_word:
            # aggregate previous word
            word_vec = torch.stack(current_vecs).mean(dim=0)

            # strip punctuation + lowercase
            clean_word = current_word.lower().strip(string.punctuation)

            if clean_word and (not skip_stopwords or clean_word not in STOPWORDS):
                usage_vectors.append({
                    "word": clean_word,
                    "vector": word_vec.cpu(),
                    "char_start": current_start,
                    "char_end": current_end
                })

            current_vecs = []

        if is_new_word:
            current_word = token.lstrip("Ġ")
            current_start = offsets[i][0].item()
            current_end = offsets[i][1].item()
            current_vecs.append(summed[i])
        else:
            current_word += token
            current_end = offsets[i][1].item()
            current_vecs.append(summed[i])

    # Handle last word
    if current_word:
        word_vec = torch.stack(current_vecs).mean(dim=0)
        clean_word = current_word.lower().strip(string.punctuation)
        if clean_word and (not skip_stopwords or clean_word not in STOPWORDS):
            usage_vectors.append({
                "word": clean_word,
                "vector": word_vec.cpu(),
                "char_start": current_start,
                "char_end": current_end
            })

    return usage_vectors

# %% [markdown]
# # Unzip each PPA page and load the JSON data

# %%
def page_iter(pages_file):
   # Yield pages one at a time from gzipped JSON lines file for memory efficiency
   with gzip.open(pages_file, 'rt', encoding='utf-8') as fh:
       for line in fh:
           yield json.loads(line)

# %% [markdown]
# # Load ModernBERT tokenizer and model

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_id = "answerdotai/ModernBERT-base"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModel.from_pretrained(model_id)

# %% [markdown]
# # Test on N Pages

# %% [markdown]
# I made an adjustment to keep all metadata fields, like title, author, and publication date, so we can include them in analysis and testing. It's hard for me to tell whether something makes sense otherwise.

# %%
TARGET_COLLECTIONS = {"Literary", "Linguistic"}
with open("Data/ppa_corpus_2025-02-03_1308/ppa_metadata.json") as f:
    metadata = json.load(f)

# index by work_id, but keep full entry
metadata_index = {
    entry["work_id"]: entry
    for entry in metadata
    if "collections" in entry and any(c in TARGET_COLLECTIONS for c in entry["collections"])
}

# %% [markdown]
# # Parameters to tweak

# %%
CORPUS_PATH = "Data/ppa_corpus_2025-02-03_1308/ppa_pages.jsonl.gz"

NUM_PAGES_TO_PROCESS = 250          # set higher once everything works
CONTEXT_PADDING = 75                # chars on each side in the context snippet
TARGET_WORDS = None                 # e.g., {"ballad", "sonnet"} or None for all

# %%
# === Text helpers ===
def normalize_whitespace(text: str) -> str:
    return re.sub(r"\s+", " ", text).strip()

def create_context_snippet(full_text: str, char_start: int, char_end: int, pad: int = CONTEXT_PADDING) -> str:
    """Return a compact context snippet with the span in **bold**."""
    if not isinstance(full_text, str) or full_text == "":
        return ""
    if not isinstance(char_start, int) or not isinstance(char_end, int):
        # Char offsets might come in as numpy types
        try:
            char_start = int(round(char_start))
            char_end = int(round(char_end))
        except Exception:
            return ""

    text_len = len(full_text)
    char_start = max(0, min(char_start, text_len))
    char_end   = max(0, min(char_end, text_len))
    if not (0 <= char_start < char_end <= text_len):
        return ""

    snippet_start = max(0, char_start - pad)
    snippet_end   = min(text_len, char_end + pad)

    text_before = normalize_whitespace(full_text[snippet_start:char_start])
    text_middle = normalize_whitespace(full_text[char_start:char_end])
    text_after  = normalize_whitespace(full_text[char_end:snippet_end])

    return f"{text_before} **{text_middle}** {text_after}"

# %% [markdown]
# # Process Pages and Grab Embeddings

# %% [markdown]
# Try random sample so it's not all 1500s and EEBO

# %%
extracted_records = []

# load everything into a list
all_pages = list(page_iter(CORPUS_PATH))

# choose N random pages
sampled_pages = random.sample(all_pages,  NUM_PAGES_TO_PROCESS)

# iterate by random sample of N pages
for page_record in sampled_pages:

# Iterate by first N number of pages
# for page_record in islice(page_iter(CORPUS_PATH), NUM_PAGES_TO_PROCESS):
    page_text = page_record.get("text")
    page_id = page_record.get("id")
    work_id = page_record.get("work_id")

    if not page_text or work_id not in metadata_index:
        continue

    work_meta = metadata_index[work_id]  # dict with title, author, pub_year, etc.

    for usage in extract_usage_representations(page_text, tokenizer, model, device=DEVICE):
        word = usage.get("word")
        if TARGET_WORDS is not None and word not in TARGET_WORDS:
            continue

        char_start = usage.get("char_start")
        char_end   = usage.get("char_end")

        context_snippet = create_context_snippet(page_text, char_start, char_end, pad=CONTEXT_PADDING)

        # Build record: base word info + flattened metadata
        record = {
            "word": word,
            "usage_vector": (usage.get("vector").tolist()
                             if hasattr(usage.get("vector"), "tolist")
                             else usage.get("vector")),
            "char_start": char_start,
            "char_end": char_end,
            "id": page_id,
            "work_id": work_id,
            "context_snippet": context_snippet,
        }

        # Merge in metadata fields
        record.update({
            "title": work_meta.get("title"),
            "author": work_meta.get("author"),
            "pub_year": work_meta.get("pub_year"),
            "pub_place": work_meta.get("pub_place"),
            "publisher": work_meta.get("publisher"),
            "source_id": work_meta.get("source_id"),
            "source_url": work_meta.get("source_url"),
            "source": work_meta.get("source"),
            "work_type": work_meta.get("work_type"),
            "collections": work_meta.get("collections"),
            "cluster_id": work_meta.get("cluster_id"),
        })

        extracted_records.append(record)

# %% [markdown]
# Make dataframe

# %%
word_usage_df = pd.DataFrame(extracted_records)

# %%
word_usage_df
# Out:
#                               word  \
# 0                            place
# 1                               of
# 2      literature.ċ7ċcontemplation
# 3                               of
# 4                            those
# ...                            ...
# 56443                           at
# 56444                   postċwhere
# 56445                        glory
# 56446                       strove
# 56447                      death.ċ
#
#                                             usage_vector  char_start  \
# 0      [-60.580474853515625, 55.52336883544922, 7.747...         3.0
# 1      [-17.78848648071289, -35.76409912109375, -16.6...         9.0
# 2      [-46.980201721191406, -22.354145050048828, -10...        12.0
# 3      [29.396236419677734, -44.41532897949219, 61.92...        40.0
# 4      [61.783241271972656, 4.421317100524902, -34.86...        43.0
# ...                                                  ...         ...
# 56443  [-49.87699890136719, -67.54403686523438, 50.85...      1221.0
# 56444  [-47.702911376953125, -55.42826461791992, -53....      1228.0
# 56445  [-78.4246826171875, -5.383387565612793, -28.63...      1239.0
# 56446  [-15.757892608642578, -37.12873077392578, 54.3...      1245.0
# 56447  [-22.721824645996094, -26.338335037231445, 19....      1257.0
#
#        char_end                           id             work_id  \
# 0             9  mdp.39015021774883.00000011  mdp.39015021774883
# 1            12  mdp.39015021774883.00000011  mdp.39015021774883
# 2            40  mdp.39015021774883.00000011  mdp.39015021774883
# 3            43  mdp.39015021774883.00000011  mdp.39015021774883
# 4            49  mdp.39015021774883.00000011  mdp.39015021774883
# ...         ...                          ...                 ...
# 56443      1224  mdp.49015000900655.00000197  mdp.49015000900655
# 56444      1239  mdp.49015000900655.00000197  mdp.49015000900655
# 56445      1245  mdp.49015000900655.00000197  mdp.49015000900655
# 56446      1252  mdp.49015000900655.00000197  mdp.49015000900655
# 56447      1265  mdp.49015000900655.00000197  mdp.49015000900655
#
#                                          context_snippet  \
# 0      THE **PLACE** OF LITERATURE. 7 contemplation o...
# 1      THE PLACE **OF** LITERATURE. 7 contemplation o...
# 2      THE PLACE OF **LITERATURE. 7 contemplation** o...
# 3      THE PLACE OF LITERATURE. 7 contemplation **of*...
# 4      THE PLACE OF LITERATURE. 7 contemplation of **...
# ...                                                  ...
# 56443  calling us by name, Struggling with failing br...
# 56444  g us by name, Struggling with failing breath T...
# 56445  e, Struggling with failing breath To keep thei...
# 56446  uggling with failing breath To keep their ship...
# 56447  failing breath To keep their shipmates at the ...
#
#                                    title                             author  \
# 0                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 1                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 2                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 3                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 4                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# ...                                  ...                                ...
# 56443  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56444  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56445  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56446  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56447  The science and art of elocution;       Fenno, Frank Honywell, 1857-
#
#        pub_year     pub_place                      publisher  \
# 0          1888        Boston  Houghton, Mifflin and company
# 1          1888        Boston  Houghton, Mifflin and company
# 2          1888        Boston  Houghton, Mifflin and company
# 3          1888        Boston  Houghton, Mifflin and company
# 4          1888        Boston  Houghton, Mifflin and company
# ...         ...           ...                            ...
# 56443      1878  Philadelphia         J. E. Porter & company
# 56444      1878  Philadelphia         J. E. Porter & company
# 56445      1878  Philadelphia         J. E. Porter & company
# 56446      1878  Philadelphia         J. E. Porter & company
# 56447      1878  Philadelphia         J. E. Porter & company
#
#                 source_id                                      source_url  \
# 0      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 1      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 2      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 3      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 4      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# ...                   ...                                             ...
# 56443  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56444  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56445  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56446  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56447  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
#
#            source  work_type                           collections  \
# 0      HathiTrust  full-work                          [Linguistic]
# 1      HathiTrust  full-work                          [Linguistic]
# 2      HathiTrust  full-work                          [Linguistic]
# 3      HathiTrust  full-work                          [Linguistic]
# 4      HathiTrust  full-work                          [Linguistic]
# ...           ...        ...                                   ...
# 56443  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56444  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56445  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56446  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56447  HathiTrust  full-work  [Linguistic, Typographically Unique]
#
#                cluster_id
# 0      mdp.39015021774883
# 1      mdp.39015021774883
# 2      mdp.39015021774883
# 3      mdp.39015021774883
# 4      mdp.39015021774883
# ...                   ...
# 56443        fennoscience
# 56444        fennoscience
# 56445        fennoscience
# 56446        fennoscience
# 56447        fennoscience
#
# [56448 rows x 18 columns]

# %% [markdown]
# # Transform embeddings to two dimensions so we can plot and compare them

# %%
# 1. pick out rows with real vectors
valid_indices = [i for i, v in word_usage_df["usage_vector"].items() if isinstance(v, (list, np.ndarray))]

# 2. stack them into a 2D array
vectors = [np.asarray(word_usage_df.at[i, "usage_vector"], dtype=float) for i in valid_indices]
vector_matrix = np.stack(vectors)

# 3. run UMAP
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, metric="cosine", random_state=42)
coords_2d = reducer.fit_transform(vector_matrix)   # shape (len(valid_indices), 2)

# 4. assign back into dataframe
word_usage_df.loc[valid_indices, "x"] = coords_2d[:, 0]
word_usage_df.loc[valid_indices, "y"] = coords_2d[:, 1]
# Out:
# /Users/melwalsh/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
word_usage_df
# Out:
#                               word  \
# 0                            place
# 1                               of
# 2      literature.ċ7ċcontemplation
# 3                               of
# 4                            those
# ...                            ...
# 56443                           at
# 56444                   postċwhere
# 56445                        glory
# 56446                       strove
# 56447                      death.ċ
#
#                                             usage_vector  char_start  \
# 0      [-60.580474853515625, 55.52336883544922, 7.747...         3.0
# 1      [-17.78848648071289, -35.76409912109375, -16.6...         9.0
# 2      [-46.980201721191406, -22.354145050048828, -10...        12.0
# 3      [29.396236419677734, -44.41532897949219, 61.92...        40.0
# 4      [61.783241271972656, 4.421317100524902, -34.86...        43.0
# ...                                                  ...         ...
# 56443  [-49.87699890136719, -67.54403686523438, 50.85...      1221.0
# 56444  [-47.702911376953125, -55.42826461791992, -53....      1228.0
# 56445  [-78.4246826171875, -5.383387565612793, -28.63...      1239.0
# 56446  [-15.757892608642578, -37.12873077392578, 54.3...      1245.0
# 56447  [-22.721824645996094, -26.338335037231445, 19....      1257.0
#
#        char_end                           id             work_id  \
# 0             9  mdp.39015021774883.00000011  mdp.39015021774883
# 1            12  mdp.39015021774883.00000011  mdp.39015021774883
# 2            40  mdp.39015021774883.00000011  mdp.39015021774883
# 3            43  mdp.39015021774883.00000011  mdp.39015021774883
# 4            49  mdp.39015021774883.00000011  mdp.39015021774883
# ...         ...                          ...                 ...
# 56443      1224  mdp.49015000900655.00000197  mdp.49015000900655
# 56444      1239  mdp.49015000900655.00000197  mdp.49015000900655
# 56445      1245  mdp.49015000900655.00000197  mdp.49015000900655
# 56446      1252  mdp.49015000900655.00000197  mdp.49015000900655
# 56447      1265  mdp.49015000900655.00000197  mdp.49015000900655
#
#                                          context_snippet  \
# 0      THE **PLACE** OF LITERATURE. 7 contemplation o...
# 1      THE PLACE **OF** LITERATURE. 7 contemplation o...
# 2      THE PLACE OF **LITERATURE. 7 contemplation** o...
# 3      THE PLACE OF LITERATURE. 7 contemplation **of*...
# 4      THE PLACE OF LITERATURE. 7 contemplation of **...
# ...                                                  ...
# 56443  calling us by name, Struggling with failing br...
# 56444  g us by name, Struggling with failing breath T...
# 56445  e, Struggling with failing breath To keep thei...
# 56446  uggling with failing breath To keep their ship...
# 56447  failing breath To keep their shipmates at the ...
#
#                                    title                             author  \
# 0                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 1                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 2                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 3                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# 4                  Literature in school:  Scudder, Horace Elisha, 1838-1902
# ...                                  ...                                ...
# 56443  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56444  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56445  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56446  The science and art of elocution;       Fenno, Frank Honywell, 1857-
# 56447  The science and art of elocution;       Fenno, Frank Honywell, 1857-
#
#        pub_year     pub_place                      publisher  \
# 0          1888        Boston  Houghton, Mifflin and company
# 1          1888        Boston  Houghton, Mifflin and company
# 2          1888        Boston  Houghton, Mifflin and company
# 3          1888        Boston  Houghton, Mifflin and company
# 4          1888        Boston  Houghton, Mifflin and company
# ...         ...           ...                            ...
# 56443      1878  Philadelphia         J. E. Porter & company
# 56444      1878  Philadelphia         J. E. Porter & company
# 56445      1878  Philadelphia         J. E. Porter & company
# 56446      1878  Philadelphia         J. E. Porter & company
# 56447      1878  Philadelphia         J. E. Porter & company
#
#                 source_id                                      source_url  \
# 0      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 1      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 2      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 3      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# 4      mdp.39015021774883  https://hdl.handle.net/2027/mdp.39015021774883
# ...                   ...                                             ...
# 56443  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56444  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56445  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56446  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
# 56447  mdp.49015000900655  https://hdl.handle.net/2027/mdp.49015000900655
#
#            source  work_type                           collections  \
# 0      HathiTrust  full-work                          [Linguistic]
# 1      HathiTrust  full-work                          [Linguistic]
# 2      HathiTrust  full-work                          [Linguistic]
# 3      HathiTrust  full-work                          [Linguistic]
# 4      HathiTrust  full-work                          [Linguistic]
# ...           ...        ...                                   ...
# 56443  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56444  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56445  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56446  HathiTrust  full-work  [Linguistic, Typographically Unique]
# 56447  HathiTrust  full-work  [Linguistic, Typographically Unique]
#
#                cluster_id          x          y
# 0      mdp.39015021774883   0.717142   1.577780
# 1      mdp.39015021774883  19.264975   4.040833
# 2      mdp.39015021774883   0.830571   1.336475
# 3      mdp.39015021774883  -1.072388  13.947363
# 4      mdp.39015021774883   2.899079  11.380541
# ...                   ...        ...        ...
# 56443        fennoscience   4.210336  12.682718
# 56444        fennoscience   1.935579  -0.815725
# 56445        fennoscience   6.181747   1.575766
# 56446        fennoscience   4.311954   0.501458
# 56447        fennoscience   0.560073   0.024743
#
# [56448 rows x 20 columns]

# %%
pd.options.display.max_rows = 400

# %%
word_usage_df['word'].value_counts()[:300]
# Out:
# word
# of           2434
# to           1599
# a            1411
# in           1363
# is            817
# as            547
# it            529
# i             478
# or            437
# be            436
# by            391
# which         374
# ċ             280
# an            243
# on            237
# all           232
# we            224
# one           216
# at            204
# ċġċ           165
# him           150
# may           149
# who           136
# what          128
# s             127
# more          126
# when          121
# so            121
# if            120
# no            120
# my            110
# other         110
# there         106
# them          102
# been          101
# any            99
# into           93
# words          91
# ii             88
# us             82
# me             79
# man            77
# such           76
# only           76
# thou           75
# v              75
# these          74
# than           74
# do             73
# great          73
# two            73
# some           72
# word           71
# like           70
# now            69
# first          69
# 1              68
# many           68
# much           67
# very           67
# then           67
# upon           66
# well           65
# must           64
# being          61
# should         61
# see            60
# n              59
# here           59
# f              58
# own            58
# time           58
# english        58
# life           57
# out            57
# without        57
# p              56
# how            56
# thy            56
# up             56
# most           55
# art            54
# where          51
# make           51
# little         51
# place          51
# c              50
# good           50
# after          50
# same           49
# your           49
# read           48
# before         48
# too            47
# also           46
# part           46
# said           46
# those          44
# long           44
# every          44
# both           43
# made           43
# thought        42
# line           42
# men            42
# 3              41
# nature         41
# fo             40
# 2              40
# yet            40
# things         40
# each           40
# used           40
# though         40
# form           40
# did            39
# shall          39
# even           39
# often          39
# know           39
# work           38
# following      38
# t              38
# old            37
# never          37
# mind           36
# mr             36
# over           36
# through        35
# ye             35
# find           34
# e              34
# take           34
# down           34
# end            34
# j              33
# about          33
# having         33
# sentence       33
# page           33
# hand           33
# nor            32
# does           32
# give           32
# subject        32
# general        32
# name           31
# another        31
# himself        31
# however        31
# love           31
# found          31
# whole          31
# power          31
# thus           31
# written        31
# called         30
# âģķ            30
# come           30
# day            30
# might          30
# again          30
# thing          30
# true           30
# way            30
# under          30
# given          29
# effect         29
# order          29
# language       29
# still          29
# came           28
# world          28
# l              28
# far            28
# father         28
# against        28
# sound          28
# ofċthe         28
# truth          27
# sense          27
# between        27
# act            27
# de             27
# am             27
# hath           26
# king           26
# latin          26
# last           26
# forms          25
# manner         25
# lord           25
# above          25
# verb           25
# among          25
# 4              25
# let            25
# think          25
# cannot         25
# history        24
# three          24
# meaning        24
# seen           24
# few            24
# common         24
# therefore      24
# people         24
# god            24
# new            23
# put            23
# means          23
# right          23
# o              23
# light          23
# fame           23
# done           23
# fuch           23
# because        23
# kind           22
# nothing        22
# praise         22
# brought        22
# say            22
# seems          22
# use            22
# soul           22
# indeed         22
# beauty         22
# child          22
# left           22
# times          22
# sax            22
# once           21
# according      21
# r              21
# since          21
# earth          21
# high           21
# full           21
# night          21
# object         20
# while          20
# heart          20
# always         20
# french         20
# person         20
# whom           20
# ever           20
# human          20
# second         20
# less           20
# set            20
# poetry         20
# case           19
# price          19
# hundred        19
# children       19
# speech         19
# lie            19
# years          19
# generally      19
# character      19
# point          19
# body           19
# others         19
# ad             19
# length         19
# action         18
# ã¼             18
# large          18
# year           18
# fr             18
# town           18
# mean           18
# says           18
# itself         18
# sometimes      18
# known          18
# hold           18
# either         18
# unto           18
# death          18
# makes          18
# reading        18
# age            18
# look           18
# knowledge      18
# syllable       17
# sounds         17
# perhaps        17
# d              17
# vowel          17
# matter         17
# inċthe         17
# et             17
# due            17
# state          17
# short          17
# city           17
# head           17
# Name: count, dtype: int64

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
# Avoid special 'title' key in tooltip
# word_usage_df = word_usage_df.rename(columns={"work_title": "title"})

# %%
chart = (
    alt.Chart(word_usage_df[:25000], title=f"PPA Word Embeddings ({NUM_PAGES_TO_PROCESS} Pages)")
    .mark_circle(size=60, opacity=0.8)
    .encode(

        x=alt.X("x:Q", scale=alt.Scale(zero=False)),
        y=alt.Y("y:Q", scale=alt.Scale(zero=False)),

        color="word:N",  

        tooltip=[
            alt.Tooltip("word:N"),
            alt.Tooltip("title"),
            alt.Tooltip("author"),
            alt.Tooltip("pub_year"),
            alt.Tooltip("id:N"),
             alt.Tooltip("context_snippet"),
            alt.Tooltip("work_id:N"),
            alt.Tooltip("char_start:Q"),
            alt.Tooltip("char_end:Q"),
        ],
    )
    .interactive()
    .properties(width=600, height=600)
)

chart

# %%
chart.save(f'PPA-{NUM_PAGES_TO_PROCESS}-random-pages.html')

# %% [markdown]
# # Selected Words

# %%
# selected_words = "ballad|ballade|ballades|epic|\bode\b|\bodes\b|sonnet|poem|poetry|haiku|prose|verse|villanelle"
selected_words = "ballad|ballade|ballades|epic|\bode\b|\bodes\b|sonnet|haiku|villanelle"

# %%
selected_words_df = word_usage_df[word_usage_df['word'].str.contains(selected_words)]

# %%
selected_words_df[:100]
# Out:
#                       word                                       usage_vector  \
# 10109              ballads  [6.527761936187744, -18.135896682739258, 51.18...
# 10263            balladist  [-33.23130798339844, 6.127866268157959, 22.657...
# 24649    hastings,ċballade  [11.652135848999023, 10.932976722717285, 113.0...
# 26446              sonnets  [-46.92252731323242, 37.66505813598633, -23.86...
# 26452          herċsonnets  [-1.5658226013183594, -27.013193130493164, -25...
# 26467         sonnetsċfrom  [-24.603464126586914, -16.128515243530273, -20...
# 26468  portuguese,-sonnets  [-52.13423538208008, 31.61355972290039, -44.25...
# 26487        theċ'sonnet's  [-27.3944091796875, -26.132200241088867, -32.6...
# 29970                 epic  [-70.58683776855469, -11.152405738830566, -31....
# 34666                 epic  [-6.0251970291137695, 18.181289672851562, -7.3...
# 45971               sonnet  [-53.34115982055664, 43.53590774536133, -17.87...
# 53148          theċsonnets  [-47.08139419555664, 15.188698768615723, 10.26...
#
#        char_start  char_end                           id             work_id  \
# 10109        61.0        69        uc1.b3861089.00000502        uc1.b3861089
# 10263      1334.0      1345        uc1.b3861089.00000502        uc1.b3861089
# 24649        65.0        83            CW0116299725.0323        CW0116299725
# 26446      1588.0      1597  mdp.39015017644959.00000630  mdp.39015017644959
# 26452      1632.0      1644  mdp.39015017644959.00000630  mdp.39015017644959
# 26467      1756.0      1769  mdp.39015017644959.00000630  mdp.39015017644959
# 26468      1773.0      1794  mdp.39015017644959.00000630  mdp.39015017644959
# 26487      1951.0      1965  mdp.39015017644959.00000630  mdp.39015017644959
# 29970       226.0       231  njp.32101013516610.00000205  njp.32101013516610
# 34666       123.0       128  njp.32101055576415.00000176  njp.32101055576415
# 45971       357.0       365          hvd.hwp8fs.00000237          hvd.hwp8fs
# 53148       524.0       536      uva.x030556810.00000299      uva.x030556810
#
#                                          context_snippet  \
# 10109  470 SONG, SENTIMENT, AND FANCY. Toru Dutt: 185...
# 10263  he world were colder. The later songs of Marzi...
# 24649  THE POETICAL WORKS Ов THOMAS CHATTERTON. ELLA,...
# 26446  chnical point of view, may be counted irreproa...
# 26452  oachable, may, if we except the Sonnets, almos...
# 26467  produced. Perhaps indeed her greatest poetic s...
# 26468  s indeed her greatest poetic success is to be ...
# 26487  aintly disguised presentment of the writer's m...
# 29970  sculpture, and regards the images of statesmen...
# 34666  is is correct, the first syllable in ἱερὸν is ...
# 45971  879 version to "plaited." "Pleached with her h...
# 53148  ke. Education, as compared with aspiration, co...
#
#                                                    title  \
# 10109                                   Victorian poets;
# 10263                                   Victorian poets;
# 24649  A complete edition of the poets of Great Brita...
# 26446                                 The English poets;
# 26452                                 The English poets;
# 26467                                 The English poets;
# 26468                                 The English poets;
# 26487                                 The English poets;
# 29970               Specimens of the forms of discourse.
# 34666                 A treatise on Greek tragic metres:
# 45971  The formation of Tennyson's style, a study, pr...
# 53148                                   Victorian poets,
#
#                                          author  pub_year pub_place  \
# 10109       Stedman, Edmund Clarence, 1833-1908      1915    Boston
# 10263       Stedman, Edmund Clarence, 1833-1908      1915    Boston
# 24649                                      None      1792   London
# 26446           Ward, Thomas Humphry, 1845-1926      1883    London
# 26452           Ward, Thomas Humphry, 1845-1926      1883    London
# 26467           Ward, Thomas Humphry, 1845-1926      1883    London
# 26468           Ward, Thomas Humphry, 1845-1926      1883    London
# 26487           Ward, Thomas Humphry, 1845-1926      1883    London
# 29970           Lewis, Edwin Herbert, 1866-1938      1900  New York
# 34666               Linwood, William, 1817-1878      1855    London
# 45971  Pyre, James Francis Augustine, 1871-1934      1921   Madison
# 53148       Stedman, Edmund Clarence, 1833-1908      1887    Boston
#
#                                                publisher           source_id  \
# 10109                                  Houghton, Mifflin        uc1.b3861089
# 10263                                  Houghton, Mifflin        uc1.b3861089
# 24649  John and Arthur Arch, and for Bell and Bradfut...        CW0116299725
# 26446                                  Macmillan and co.  mdp.39015017644959
# 26452                                  Macmillan and co.  mdp.39015017644959
# 26467                                  Macmillan and co.  mdp.39015017644959
# 26468                                  Macmillan and co.  mdp.39015017644959
# 26487                                  Macmillan and co.  mdp.39015017644959
# 29970                                H. Holt and company  njp.32101013516610
# 34666                 Longman, Brown, Green and Longmans  njp.32101055576415
# 45971                                               None          hvd.hwp8fs
# 53148                                  Houghton, Mifflin      uva.x030556810
#
#                                               source_url      source  \
# 10109           https://hdl.handle.net/2027/uc1.b3861089  HathiTrust
# 10263           https://hdl.handle.net/2027/uc1.b3861089  HathiTrust
# 24649  https://link.gale.com/apps/doc/CW0116299725/EC...        Gale
# 26446     https://hdl.handle.net/2027/mdp.39015017644959  HathiTrust
# 26452     https://hdl.handle.net/2027/mdp.39015017644959  HathiTrust
# 26467     https://hdl.handle.net/2027/mdp.39015017644959  HathiTrust
# 26468     https://hdl.handle.net/2027/mdp.39015017644959  HathiTrust
# 26487     https://hdl.handle.net/2027/mdp.39015017644959  HathiTrust
# 29970     https://hdl.handle.net/2027/njp.32101013516610  HathiTrust
# 34666     https://hdl.handle.net/2027/njp.32101055576415  HathiTrust
# 45971             https://hdl.handle.net/2027/hvd.hwp8fs  HathiTrust
# 53148         https://hdl.handle.net/2027/uva.x030556810  HathiTrust
#
#        work_type                                        collections  \
# 10109  full-work                                         [Literary]
# 10263  full-work                                         [Literary]
# 24649  full-work                                         [Literary]
# 26446  full-work                                         [Literary]
# 26452  full-work                                         [Literary]
# 26467  full-work                                         [Literary]
# 26468  full-work                                         [Literary]
# 26487  full-work                                         [Literary]
# 29970  full-work                             [Linguistic, Literary]
# 34666  full-work                                         [Literary]
# 45971  full-work  [Literary, Original Bibliography, Typographica...
# 53148  full-work                                         [Literary]
#
#                cluster_id          x         y
# 10109    stedmanvictorian   3.414447  1.680198
# 10263    stedmanvictorian   3.645900  0.861837
# 24649        CW0116299725  13.836024  3.527303
# 26446        wardenglish4   2.903377  1.004287
# 26452        wardenglish4   2.987388  0.914640
# 26467        wardenglish4   2.921550  0.836014
# 26468        wardenglish4   2.912977  0.977733
# 26487        wardenglish4   2.955377  0.301105
# 29970  njp.32101013516610   4.185784  1.388377
# 34666  njp.32101055576415   3.134956  1.368462
# 45971          hvd.hwp8fs   2.967115  1.138020
# 53148    stedmanvictorian   2.991663  0.548061

# %%
chart2 = (
    alt.Chart(selected_words_df, title="PPA Word Usage (Sonnet, Ballad, Epic)")
    .mark_circle(size=60, opacity=0.8)
    .encode(
        x=alt.X("x:Q", scale=alt.Scale(zero=False)),
        y=alt.Y("y:Q", scale=alt.Scale(zero=False)),
        color="word:N",  # or cluster labels if too many unique words
        tooltip=[
            alt.Tooltip("title:N"),

            alt.Tooltip("word:N"),
            alt.Tooltip("context_snippet"),
            alt.Tooltip("pub_year"),
             alt.Tooltip("author"),

            # alt.Tooltip("id:N"),
            # alt.Tooltip("work_id:N"),
            # alt.Tooltip("char_start:Q"),
            # alt.Tooltip("char_end:Q"),
        ],
    )
    .interactive()
    .properties(width=600, height=600)
)

chart2
# Out:
# alt.Chart(...)

# %%
chart2.save('PPA-random-pages_sonnet-ballad-epic.html')
