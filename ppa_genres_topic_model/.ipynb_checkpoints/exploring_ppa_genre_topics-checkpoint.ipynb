# %%
#!pip install little_mallet_wrapper

# %%
import pandas as pd
import re

from collections import defaultdict
from datetime import datetime
import math
from operator import itemgetter
import os
import random
import glob
from pathlib import Path

import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import little_mallet_wrapper as lmw

pd.set_option('display.max_rows', 100)

# %% [markdown]
# <h2>Load topic model</h2>

# %%
num_topics=100
output_directory_path = 'topic-model-output/ppa-100-topics_all/'


Path(f"{output_directory_path}").mkdir(parents=True, exist_ok=True)

path_to_training_data           = f"{output_directory_path}/training.txt"
path_to_formatted_training_data = f"{output_directory_path}/mallet.training"
path_to_model                   = f"{output_directory_path}/mallet.model.{str(num_topics)}"
path_to_topic_keys              = f"{output_directory_path}/mallet.topic_keys.{str(num_topics)}"
path_to_topic_distributions     = f"{output_directory_path}/mallet.topic_distributions.{str(num_topics)}"

# %%
path_to_training_data[0:500]
# Out:
# 'topic-model-output/ppa-100-topics_all//training.txt'

# %%
topics = lmw.load_topic_keys(path_to_topic_keys)

for topic_number, topic in enumerate(topics):
    print(f"✨Topic {topic_number}✨\n\n{topic}\n")
# Out:
# ✨Topic 0✨
#
# ['verse', 'rhythm', 'line', 'lines', 'prose', 'blank', 'one', 'metrical', 'may', 'syllables', 'time', 'two', 'music', 'words', 'form', 'metre', 'pause', 'english', 'end', 'use']
#
# ✨Topic 1✨
#
# ['sir', 'john', 'william', 'song', 'browne', 'thomas', 'drayton', 'jonson', 'george', 'donne', 'love', 'ben', 'lord', 'iii', 'death', 'wither', 'herrick', 'poems', 'note', 'drummond']
#
# ✨Topic 2✨
#
# ['years', 'life', 'year', 'published', 'born', 'poems', 'died', 'college', 'first', 'london', 'time', 'one', 'cambridge', 'death', 'poet', 'became', 'work', 'father', 'oxford', 'two']
#
# ✨Topic 3✨
#
# ['chaucer', 'tale', 'lydgate', 'see', 'gower', 'french', 'balade', 'english', 'love', 'may', 'mss', 'tales', 'poem', 'iii', 'also', 'thou', 'god', 'king', 'poems', 'ant']
#
# ✨Topic 4✨
#
# ...

# %%
topic_distributions = lmw.load_topic_distributions(path_to_topic_distributions)

# %% [markdown]
# <h2>Get documents</h2>

# %%
df=pd.read_csv("filtered_ppa_corpus.csv")

# %%
df["pub_year"] = pd.to_numeric(df["pub_year"], errors="coerce")

df = df[(df["pub_year"] >= 1559) & (df["pub_year"] <= 1929)].copy()

# %%
training_data = [lmw.process_string(text, numbers='remove') for text in df['page_text']]

# %%
original_texts = [text for text in df['page_text']]

page_ids = [title for title in df['page_id']]

training_data_page_ids = dict(zip(training_data, page_ids))

training_data_original_text = dict(zip(training_data, original_texts))

# %%
training_data[1]
# Out:
# 'salust semaine reglant ensemblement nos moeurs nos humeurs troublant ensemblement nos humeurs nos moeurs boscan assi està vida mia todo desconsolada cuerpo desamparada fuera alegria pues vos apartada cap epanalepsis repetitions place two following epanalepsis epanados diuerslie placed epanalepsis resu ption sound iterated beginning ending virg aen multa super priamo rogitans super hectore multa aeg ambo florentes atibus arcades ambo georg nudus ara sere nudus aeg occidet serpens fallax herba veneni occidet aeg tityre dum redeo breuis est via pasce capellas potum pastas age tityre georg amba auro pictis incincta pellibus amba aeneid arma viri ferte arma aeneid victus amore tui cognato sanguine victus socer arua latinus habebat imperium solenne socer sir syd feare paine paine feares sonet loue indeed quake say loue hark plaintfull ghosts infernall furies hark gynecia thoughts ouerflowings mind tongue seruant thoughts torquat tass audace cautamente audace torris aluida estingua tutti g
# ...

# %%
training_data[0]
# Out:
# 'verse one adoniu added thereunto iam satis terris niuis atque dira grandinis misit pater rubento dextera sacras iaculatus arces terruit vrbem sir philip sydney cleophila looking philoclea speaketh hope mine eyes speake doo heartie arrant mine eyes language doo hap iudge eyes message receiued hope doo liue yet eyes faile doo need eyes language vnto knowne eyes message doo returne reiected hope doo dye yet dying dead doo sing honour become tombes monuments praise become losses triumph gaine glorie remy belleau hath kind fremis tremblant frisson saisist palle blesmis comme herbe des champs sans chaleur sans poux amoreuse langueur presq transis thirdly lastly elegum elegiacall verse dactylus spondaeus first place third place spondaeus two anapaesti turpe quid ausurus sine teste time'

# %%
original_texts[0]
# Out:
# "\nverse, one Adoniū be added thereunto, as\n\nIam satis terris niuis, atque dira\nGrandinis misit pater, & rubento\nDextera sacras iaculatus arces\nterruit vrbem.\nSir Philip Sydney 1. Cleophila looking on Philoclea, speaketh to Hope.\n\nIf mine eyes can speake to doo heartie arrant,\nOr mine eyes language she doo hap to iudge of,\nSo that eyes message be of her receiued:\nHope, we doo liue yet.\n\n\nBut if eyes faile then, when I most doo need them,\nOr if eyes language be not vnto her knowne,\nSo that eyes message doo returne reiected,\nHope, we doo both dye.\n\n\nYet dying and dead doo we sing her honour,\nSo become our tombes monuments of her praise,\nSo become our losses the triumph of her gaine,\nHers be the glorie, &c.\n\nRemy Belleau hath some of this kind, as\n\nIe fremis tremblant, le frisson me saisist,\nPalle ie blesmis comme l'herbe des champs,\nSans chaleur, sans poux, d'amoreuse langueur\nPresq ie transis, &c.\nThirdly and lastly, Elegum, or the Elegiacall verse of a
# ...

# %%
next(iter(training_data_original_text.items()))
# Out:
# ('verse one adoniu added thereunto iam satis terris niuis atque dira grandinis misit pater rubento dextera sacras iaculatus arces terruit vrbem sir philip sydney cleophila looking philoclea speaketh hope mine eyes speake doo heartie arrant mine eyes language doo hap iudge eyes message receiued hope doo liue yet eyes faile doo need eyes language vnto knowne eyes message doo returne reiected hope doo dye yet dying dead doo sing honour become tombes monuments praise become losses triumph gaine glorie remy belleau hath kind fremis tremblant frisson saisist palle blesmis comme herbe des champs sans chaleur sans poux amoreuse langueur presq transis thirdly lastly elegum elegiacall verse dactylus spondaeus first place third place spondaeus two anapaesti turpe quid ausurus sine teste time',
# ...

# %%
def display_top_titles_per_topic(topic_number, number_of_documents):
    
    print(f"✨Topic {topic_number}✨\n\n{topics[topic_number]}\n")

    for probability, document in lmw.get_top_docs(training_data, topic_distributions, topic_number, n=number_of_documents):
        print(round(probability, 4), training_data_page_ids[document] + "\n")
    return

# %%
display_top_titles_per_topic(topic_number=99, number_of_documents=5)
# Out:
# ✨Topic 99✨
#
# ['poetry', 'lyric', 'ode', 'odes', 'may', 'didactic', 'poetical', 'form', 'great', 'much', 'species', 'poet', 'kind', 'horace', 'character', 'composition', 'one', 'book', 'david', 'many']
#
# 0.995 hvd.32044102845872.00000416
#
# 0.995 nyp.33433082515549.00000428
#
# 0.995 nyp.33433082515549.00000428
#
# 0.995 nyp.33433082515606.00000422
#
# 0.995 hvd.hn6imd.00000422

# %%
from IPython.display import Markdown, display
import re

def display_bolded_topic_words_in_context(topic_number=114, number_of_documents=10, custom_words=None):

    for probability, document in lmw.get_top_docs(training_data, topic_distributions, topic_number, n=number_of_documents):
        
        print(f"✨Topic {topic_number}✨\n\n{topics[topic_number]}\n")
        
        probability = f"✨✨✨\n\n**{probability}**"
        page_id = f"**{training_data_page_ids[document]}**"
        original_text = training_data_original_text[document]
        topic_words = topics[topic_number]
        topic_words = custom_words if custom_words != None else topic_words

        for word in topic_words:
            if word in original_text:
                original_text = re.sub(f"\\b{word}\\b", f"**{word}**", original_text)

        display(Markdown(probability)), display(page_id), display(Markdown(original_text))
    return

# %%
display_bolded_topic_words_in_context(topic_number=87, number_of_documents=100)
# Out:
# ✨Topic 87✨
#
# ['spenser', 'sir', 'english', 'surrey', 'sidney', 'thomas', 'wyatt', 'queen', 'lord', 'elizabeth', 'henry', 'sonnets', 'poetry', 'philip', 'england', 'earl', 'fol', 'see', 'poets', 'poet']
# ✨✨✨
#
# **0.9860057318879389**
# '**nyp.33433074792502.00000247**'
# THE TABLE.
# Songs.
# Edm. Spen.
# John Wootton.
# Thom. Lodge.
# Authors.
# Harpalus complaint on Philladae's loue bestowed on Corin, who loued her not and denyed
# him that loued her.....
# L. T. Howard, Earle of Surrie,
# Another of the same subiect but made as it were in answere...
# Shep. Tonie.
# The Nimphes meeting their May Queene, entertaine her with this dittie... Tho. Watson.
# Colin Cloute's mournfull dittie for the death of Astrophell..
# Damætas ligge in praise of his Loue.
# Montanus praise of his faire Phæbe.
# The Complaint of Thestilis the forsaken Shepheard.
# To Phillis the faire Shepheardesse....
# The Shepheard Doron's ligge....
# Astrophell his Song of Phillida and Coridon
# ...

# %% [markdown]
# <h2>Topics of interest</h2>

# %%
#Topic 7

display_bolded_topic_words_in_context(topic_number=7, number_of_documents=10)
# Out:
# ✨Topic 7✨
#
# ['john', 'william', 'born', 'song', 'quoted', 'robert', 'died', 'thomas', 'england', 'charles', 'henry', 'james', 'love', 'george', 'london', 'ballad', 'mrs', 'old', 'richard', 'living']
# ✨✨✨
#
# **0.9947229776556218**
# '**uc1.$b248085.00001927**'
# Index of Authors
# 3883
# LETTS, WINIFRED, M.
# An Irish writer, now **living** in Drehlin.
# The Spires of Oxford...... 2560
# LOCKHART, JOHN GIBSON
# Born at Cambusnethan, Scotland,
# July 14, 1701; **died** at Abbotsford,
# November 25, 1854.
# The Wandering Knight's
# Song
# 626
# Lever. Charles JAMES
# Born at Dublin, Ireland, August 31,
# 1800; **died** at Triest, Austria-Hungary,
# June 1, 1872.
# "The Pope He Leads a
# Happy Life"
# 2137
# The Widow Malone.
# 1973
# LEWIS, MATTHEW GREGORY
# Born in London, England, July 9,
# 1775; **died** at sea, oj yellow fever,
# May 14. 1818.
# Allan Water..
# 1042
# LIDDELL, CATHERINE C.
# An English writer, **born** in 1818.
# Jesus the Carpenter.
# 3768
# ...

# %%
#Topic 14 BALLAD

display_bolded_topic_words_in_context(topic_number=14, number_of_documents=20)
# Out:
# ✨Topic 14✨
#
# ['ver', 'fame', 'one', 'fome', 'fir', 'called', 'two', 'hed', 'alfo', 'thefe', 'engli', 'time', 'see', 'among', 'many', 'firft', 'fays', 'made', 'tran', 'thus']
# ✨✨✨
#
# **0.8178864896297893**
# '**CW0115141404.0249**'
# Ch. I. 2.
# AND MUSIC.
# 243
# farge, cavern, honey, career, cincture, bo-
# fom, fphere, are common nouns; but, to
# bymn, to pillow, curtained, pillared, pictured,
# pealing, Jurging, cavern'd, honied, careering,
# cinctured, bofomed, Sphered, would appear af-
# fected in profe, though in verſe they are
# warranted by the very beft authority.
# Some late poets, particularly the imitators
# of Spenfer, have introduced a great variety
# of uncommon words, as certes, eftfoons, ne,
# whilom, tranfmew, moil, fone, lofel, albe,
# hight, dight, pight, thews, couthful, affot,
# I fhould ill confult my own credit, if I were to op-
# pofe my judgement to that of this able critic and ex-
# cellent author. Yet I would beg leave to fay, that to me
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_topic_over_time(topic_number, agg="mean", threshold=None, min_docs_per_year=1, smooth_window=None):
    if agg == "share_above_threshold" and threshold is None:
        raise ValueError("If agg='share_above_threshold', you must supply a threshold (e.g., 0.05).")

    # --- list-safe extraction (works for list-of-lists OR numpy array) ---
    topic_weights = [row[topic_number] for row in topic_distributions]

    # --- sanity check: lengths must align ---
    if len(topic_weights) != len(df):
        raise ValueError(
            f"Row mismatch: len(topic_distributions)={len(topic_weights)} but len(df)={len(df)}. "
            "These must match 1:1 (same filtering/order) before plotting."
        )

    plot_df = df[["pub_year"]].reset_index(drop=True).copy()
    plot_df["topic_weight"] = topic_weights

    plot_df = plot_df.dropna(subset=["pub_year"])
    plot_df["pub_year"] = plot_df["pub_year"].astype(int)

    if agg == "mean":
        yearly = plot_df.groupby("pub_year")["topic_weight"].mean()
        ylab = "Average topic weight (per doc)"
        title = f"Topic {topic_number}: average weight over time"
    elif agg == "sum":
        yearly = plot_df.groupby("pub_year")["topic_weight"].sum()
        ylab = "Total topic weight (sum across docs)"
        title = f"Topic {topic_number}: total weight over time"
    elif agg == "median":
        yearly = plot_df.groupby("pub_year")["topic_weight"].median()
        ylab = "Median topic weight (per doc)"
        title = f"Topic {topic_number}: median weight over time"
    elif agg == "share_above_threshold":
        yearly = plot_df.groupby("pub_year")["topic_weight"].apply(lambda s: (s >= threshold).mean())
        ylab = f"Share of docs with topic ≥ {threshold}"
        title = f"Topic {topic_number}: share above threshold over time"
    else:
        raise ValueError("agg must be one of: mean, sum, median, share_above_threshold")

    doc_counts = plot_df.groupby("pub_year").size()
    keep_years = doc_counts[doc_counts >= min_docs_per_year].index
    yearly = yearly.loc[keep_years].sort_index()

    if smooth_window is not None and smooth_window > 1:
        yearly_to_plot = yearly.rolling(window=smooth_window, center=True, min_periods=1).mean()
        title += f" (smoothed, window={smooth_window})"
    else:
        yearly_to_plot = yearly

    plt.figure(figsize=(12, 6))
    plt.plot(yearly_to_plot.index, yearly_to_plot.values)
    plt.xlabel("Publication year")
    plt.ylabel(ylab)
    plt.title(title)
#     plt.ylim(0, .21) 
    plt.tight_layout()
    plt.show()

    return yearly

# %%
plot_topic_over_time(topic_number=4, agg="mean")
# Out:
# pub_year
# 1559    0.009146
# 1567    0.000047
# 1570    0.000028
# 1575    0.000031
# 1584    0.000052
#           ...
# 1925    0.000792
# 1926    0.001323
# 1927    0.002481
# 1928    0.001954
# 1929    0.015728
# Name: topic_weight, Length: 265, dtype: float64

# %%
plot_topic_over_time(topic_number=22, agg="median")
# Out:
# pub_year
# 1559    0.000129
# 1567    0.000159
# 1570    0.000090
# 1575    0.000128
# 1584    0.000153
#           ...
# 1925    0.000103
# 1926    0.000117
# 1927    0.000113
# 1928    0.000110
# 1929    0.000160
# Name: topic_weight, Length: 265, dtype: float64

# %%
plot_topic_over_time(topic_number=22, agg="mean")
# Out:
# pub_year
# 1559    0.000152
# 1567    0.000152
# 1570    0.000090
# 1575    0.089676
# 1584    0.000170
#           ...
# 1925    0.006878
# 1926    0.009700
# 1927    0.063359
# 1928    0.016944
# 1929    0.100063
# Name: topic_weight, Length: 265, dtype: float64

# %%
plot_topic_over_time(topic_number=45, agg="mean")
# Out:
# pub_year
# 1559    0.000194
# 1567    0.003446
# 1570    0.000115
# 1575    0.018851
# 1584    0.004545
#           ...
# 1925    0.018433
# 1926    0.013723
# 1927    0.012591
# 1928    0.047649
# 1929    0.024811
# Name: topic_weight, Length: 265, dtype: float64

# %%
plot_topic_over_time(topic_number=4, agg="mean")
# Out:
# pub_year
# 1559    0.009146
# 1567    0.000047
# 1570    0.000028
# 1575    0.000031
# 1584    0.000052
#           ...
# 1925    0.000792
# 1926    0.001323
# 1927    0.002481
# 1928    0.001954
# 1929    0.015728
# Name: topic_weight, Length: 265, dtype: float64

# %%
plot_topic_over_time(topic_number=64, agg="mean")
# Out:
# pub_year
# 1559    0.000101
# 1567    0.008967
# 1570    0.000060
# 1575    0.000067
# 1584    0.000114
#           ...
# 1925    0.008795
# 1926    0.000974
# 1927    0.009336
# 1928    0.005807
# 1929    0.004077
# Name: topic_weight, Length: 265, dtype: float64

# %%
plot_topic_over_time(topic_number=69, agg="mean")
# Out:
# pub_year
# 1559    0.000080
# 1567    0.002694
# 1570    0.000048
# 1575    0.000053
# 1584    0.000090
#           ...
# 1925    0.000899
# 1926    0.006529
# 1927    0.001780
# 1928    0.000763
# 1929    0.000359
# Name: topic_weight, Length: 265, dtype: float64

# %%
plot_topic_over_time(topic_number=64, agg="mean")
# Out:
# pub_year
# 1559    0.000101
# 1567    0.008967
# 1570    0.000060
# 1575    0.000067
# 1584    0.000114
#           ...
# 1925    0.008795
# 1926    0.000974
# 1927    0.009336
# 1928    0.005807
# 1929    0.004077
# Name: topic_weight, Length: 265, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_four_topics_over_time(
    topic_numbers,
    agg="mean",
    threshold=None,
    min_docs_per_year=1,
    smooth_window=None,
    y_max=0.25
):
    """
    Plot four topics side-by-side with shared x-axis.

    topic_numbers : list of exactly four ints
    """

    assert len(topic_numbers) == 4, "Please pass exactly four topic numbers."

    fig, axes = plt.subplots(
        nrows=1,
        ncols=4,
        figsize=(18, 5),
        sharex=True,
        sharey=True
    )

    for ax, topic_number in zip(axes, topic_numbers):

        # --- list-safe topic extraction ---
        topic_weights = [row[topic_number] for row in topic_distributions]

        if len(topic_weights) != len(df):
            raise ValueError(
                f"Row mismatch for topic {topic_number}: "
                f"{len(topic_weights)} topic rows vs {len(df)} df rows"
            )

        plot_df = df[["pub_year"]].reset_index(drop=True).copy()
        plot_df["topic_weight"] = topic_weights
        plot_df = plot_df.dropna(subset=["pub_year"])
        plot_df["pub_year"] = plot_df["pub_year"].astype(int)

        # --- aggregation ---
        if agg == "mean":
            yearly = plot_df.groupby("pub_year")["topic_weight"].mean()
            ylab = "Avg topic weight"
        elif agg == "sum":
            yearly = plot_df.groupby("pub_year")["topic_weight"].sum()
            ylab = "Total topic weight"
        elif agg == "median":
            yearly = plot_df.groupby("pub_year")["topic_weight"].median()
            ylab = "Median topic weight"
        elif agg == "share_above_threshold":
            if threshold is None:
                raise ValueError("threshold required for share_above_threshold")
            yearly = plot_df.groupby("pub_year")["topic_weight"].apply(
                lambda s: (s >= threshold).mean()
            )
            ylab = f"Share ≥ {threshold}"
        else:
            raise ValueError("Invalid agg")

        # --- drop sparse years ---
        doc_counts = plot_df.groupby("pub_year").size()
        keep_years = doc_counts[doc_counts >= min_docs_per_year].index
        yearly = yearly.loc[keep_years].sort_index()

        # --- optional smoothing ---
        if smooth_window is not None and smooth_window > 1:
            yearly = yearly.rolling(
                window=smooth_window,
                center=True,
                min_periods=1
            ).mean()

        # --- plot ---
        ax.plot(yearly.index, yearly.values)
        ax.set_title(f"Topic {topic_number}")
        ax.set_ylim(0, y_max)

    # --- shared labels ---
    fig.supxlabel("Publication year")
    fig.supylabel(ylab)

    plt.tight_layout()
    plt.show()

# %%
plot_four_topics_over_time(
    topic_numbers=[4, 22, 64, 69],
    agg="mean",
#     y_max=0.1,
    smooth_window=0,
    min_docs_per_year=1
)

# %%
plot_four_topics_over_time(
    topic_numbers=[4, 22, 45, 69],
    agg="mean",
    y_max=0.07,
    smooth_window=5,
    min_docs_per_year=10
)

# %%
plot_four_topics_over_time(
    topic_numbers=[16, 18, 20, 64],
    agg="mean",
    y_max=0.15,
    smooth_window=5,
    min_docs_per_year=10
)

# %%
import matplotlib.pyplot as plt
import math
import pandas as pd

def plot_topics_over_time(
    topic_numbers,
    topic_labels=None,          # <-- pass list OR dict for custom text labels
    agg="mean",
    threshold=None,
    min_docs_per_year=1,
    smooth_window=None,
    y_max=0.25,
    ncols=4,                    # <-- controls wrapping
    figsize_per_plot=(4.5, 3.2) # <-- size per subplot (width, height)
):
    """
    Plot any number of topics as small multiples (grid of subplots) with shared axes.

    Requires:
      - topic_distributions: list/array-like shaped (n_docs, n_topics)
      - df: dataframe aligned 1:1 with topic_distributions rows, with column 'pub_year'

    topic_numbers: list[int]
    topic_labels:
        - None (default): titles like "Topic 12"
        - list[str] same length as topic_numbers
        - dict[int, str] mapping topic_number -> label
    """

    if not isinstance(topic_numbers, (list, tuple)) or len(topic_numbers) == 0:
        raise ValueError("topic_numbers must be a non-empty list of ints")

    # ---- normalize labels into a dict: topic -> label ----
    label_map = {}
    if topic_labels is None:
        label_map = {t: f"Topic {t}" for t in topic_numbers}
    elif isinstance(topic_labels, dict):
        label_map = {t: topic_labels.get(t, f"Topic {t}") for t in topic_numbers}
    elif isinstance(topic_labels, (list, tuple)):
        if len(topic_labels) != len(topic_numbers):
            raise ValueError("If topic_labels is a list, it must match topic_numbers length")
        label_map = {t: lab for t, lab in zip(topic_numbers, topic_labels)}
    else:
        raise ValueError("topic_labels must be None, a dict, or a list/tuple")

    # ---- grid layout ----
    n_topics = len(topic_numbers)
    ncols = max(1, int(ncols))
    nrows = math.ceil(n_topics / ncols)

    fig_w = figsize_per_plot[0] * ncols
    fig_h = figsize_per_plot[1] * nrows

    fig, axes = plt.subplots(
        nrows=nrows,
        ncols=ncols,
        figsize=(fig_w, fig_h),
        sharex=True,
        sharey=True
    )

    # axes might be 1D or 2D depending on nrows/ncols; flatten for easy iteration
    axes = axes.flatten() if isinstance(axes, (list, tuple)) or hasattr(axes, "flatten") else [axes]

    ylab = None  # set once based on agg

    for i, topic_number in enumerate(topic_numbers):
        ax = axes[i]

        # --- list-safe topic extraction ---
        topic_weights = [row[topic_number] for row in topic_distributions]

        if len(topic_weights) != len(df):
            raise ValueError(
                f"Row mismatch for topic {topic_number}: "
                f"{len(topic_weights)} topic rows vs {len(df)} df rows"
            )

        plot_df = df[["pub_year"]].reset_index(drop=True).copy()
        plot_df["topic_weight"] = topic_weights
        plot_df = plot_df.dropna(subset=["pub_year"])
        plot_df["pub_year"] = plot_df["pub_year"].astype(int)

        # --- aggregation ---
        if agg == "mean":
            yearly = plot_df.groupby("pub_year")["topic_weight"].mean()
            ylab = ylab or "Avg topic weight"
        elif agg == "sum":
            yearly = plot_df.groupby("pub_year")["topic_weight"].sum()
            ylab = ylab or "Total topic weight"
        elif agg == "median":
            yearly = plot_df.groupby("pub_year")["topic_weight"].median()
            ylab = ylab or "Median topic weight"
        elif agg == "share_above_threshold":
            if threshold is None:
                raise ValueError("threshold required for share_above_threshold")
            yearly = plot_df.groupby("pub_year")["topic_weight"].apply(
                lambda s: (s >= threshold).mean()
            )
            ylab = ylab or f"Share ≥ {threshold}"
        else:
            raise ValueError("Invalid agg")

        # --- drop sparse years ---
        doc_counts = plot_df.groupby("pub_year").size()
        keep_years = doc_counts[doc_counts >= min_docs_per_year].index
        yearly = yearl

# %%
topics_to_plot = [4, 22, 45, 69, 16, 18, 20, 64,]

labels = {
    3:  "imperial administration / officials",
    10: "missionary discourse",
    22: "poetics / lyric form",
    41: "print / publishing",
    57: "race / diaspora",
    88: "India / nationalism"
}

plot_topics_over_time(
    topics_to_plot,
    topic_labels=labels,
    agg="share_above_threshold",
    threshold=0.05,
    smooth_window=3,
    ncols=3,
    y_max=0.6
)

# %%
#Topic 21 BALLAD

display_bolded_topic_words_in_context(topic_number=21, number_of_documents=20)
# Out:
# ✨Topic 21✨
#
# ['one', 'time', 'years', 'would', 'first', 'life', 'could', 'great', 'upon', 'many', 'year', 'made', 'much', 'might', 'long', 'said', 'man', 'poet', 'friend', 'day']
# ✨✨✨
#
# **0.966159251759058**
# '**mdp.39015011428706.00000884**'
# 96
# NOVALIS.
# family. Here he read me the Disciples at Sais, and **many** of
# liis Hagments. He escorted me as far as Halle ; and we en-
# joyed in Giebickenstein, in the Riechardts' house, some other
# delightful hours. About this **time**, the **first** thought of his
# Ofterdingen had occurred. At an earlier period, certain of his
# Spiritual Songs had been composed: they were to form part of
# a Christian Hymn-book, which he meant to accompany with a
# collection of Sermons For the rest, he was very diligent in
# his professional labours ; whatever he did was done with the
# heart; the smallest concern was not insignificant to him.'
# The professional labours here alluded to, seem to have
# ...

# %%
#Topic 32

display_bolded_topic_words_in_context(topic_number=32, number_of_documents=20)
# Out:
# ✨Topic 32✨
#
# ['poetry', 'much', 'style', 'poet', 'language', 'one', 'though', 'may', 'poets', 'great', 'poetical', 'verse', 'without', 'genius', 'even', 'many', 'best', 'poem', 'less', 'would']
# ✨✨✨
#
# **0.9182636282816765**
# '**mdp.39015004994771.00000203**'
# BIOGRAPHIA LITERARIA.
# ISE
# on subjects of deep or curious interest rather than criticisms on
# particular works)—I look in vain for any writer, who has con-
# veyed so **much** information, from so **many** and such recondite
# sources, with so **many** just and original reflections, in a **style** so
# lively and poignant, yet so uniformly classical and perspicuous;
# no **one**, in short, who has combined so **much** wisdom with so **much**
# wit; so **much** truth and knowledge with so **much** life and fancy.
# His prose is always intelligible and always entertaining. In
# **poetry** he has attempted almost every species of composition
# known before, and he has added new ones; and if we except the
# ...

# %%
#Topic 35 BALLAD / SONG

display_bolded_topic_words_in_context(topic_number=35, number_of_documents=20)
# Out:
# ✨Topic 35✨
#
# ['epic', 'much', 'work', 'author', 'poets', 'great', 'one', 'poem', 'fenelon', 'mythology', 'telemachus', 'figure', 'religion', 'history', 'poetry', 'employed', 'life', 'adventures', 'allegory', 'country']
# ✨✨✨
#
# **0.9951132744489231**
# '**nyp.33433082515549.00000456**'
# 446
# [LECT. XLIV.
# GAMOENS' LUSIAD.
# dramatic; sometimes, but not often, sentimental; but in narration
# and description, perhaps no poet ever went beyond him. He makes
# every scene which he describes, and every event which he relates, pass
# before our eyes; and in his selection of circumstances, is eminently
# picturesque. His style is **much** varied, always suited to the subject,
# and adorned with a remarkably smooth and melodious versification.
# As the Italians make their boast of Tasso, so do the Portuguese of Ca-
# moens; who was nearly cotemporary with Tasso, but whose **poem** was
# published before the Jerusalem. The subject of it is the first discove-
# ...

# %%
#Topic 63 Ballad

display_bolded_topic_words_in_context(topic_number=63, number_of_documents=20)
# Out:
# ✨Topic 63✨
#
# ['text', 'notes', 'poetry', 'criticism', 'index', 'see', 'verse', 'english', 'ode', 'xlii', 'xlix', 'life', 'poem', 'works', 'xliii', 'composition', 'xcvii', 'structure', 'xxxvi', 'characteristics']
# ✨✨✨
#
# **0.9949053254961413**
# '**uc1.$b316547.00000711**'
# INDEX
# 593
# For: se
# -lxxxii
# 15; the
# **notes**
# **poem**,
# Spen-
# sion of,
# S, 114-
# nces of
# 99-5041
# Cvi; as
# nature
# second
# terms,
# emarks
# res of
# teristics
# literary
# English
# be emo-
# rdering
# Lxxvi;
# definition and kinds of, lxxvi-lxxix; | SHAKESPEARE WILLIAM, his position
# masculine, lxxvii; feminine, lxxvii; re-
# lation to harmony and melody in **verse**,
# lxxvi-lxxix
# in English literature, 37, 48; metre of
# his plays, 37; his sonnets, xxxvii, 462;
# a creative and interpretative poet,
# xxxiv, xxxv. For examples of his son-
# nets, **see** Sonnets of Shakespeare under
# this **index**
# Rhyme-royal, lxxxii
# Rhythm, - a mode of nature and art,
# ...

# %%
#Topic 89 BALLADE

display_bolded_topic_words_in_context(topic_number=89, number_of_documents=20)
# Out:
# ✨Topic 89✨
#
# ['see', 'comp', 'note', 'milton', 'iii', 'word', 'one', 'old', 'used', 'sense', 'notes', 'gray', 'time', 'meaning', 'part', 'explain', 'meant', 'name', 'poet', 'latin']
# ✨✨✨
#
# **0.9952693491722394**
# '**mdp.39015059901184.00000387**'
# GRAY.
# 339
# There is much "poetical license" in the topographical description of this scene.
# The details cannot be realized. Probably the height on which the bard stands is **meant** for
# Pen-maen-mawr. See Lycid. 52. Snowdon is of course **used** here in a very wide **sense**.
# 11. shaggy. See Lycid. 54.
# 13. Glo'ster.
# Gilbert de Clare, Earl of Gloucester and Hereford, had, in 1282, con-
# ducted the war in South Wales; and after overthrowing the enemy near Llandeilo Fawr, had
# reinforced the King in the North-west. See Miss Williams' Hist. of Wales, chap. xxii.
# 14. Mortimer. Edward de Mortimer actively co-operated with the King in North
# ...

# %%
#Topic 123 HYMN

display_bolded_topic_words_in_context(topic_number=123, number_of_documents=20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 #Topic 123 HYMN
# ----> 3 display_bolded_topic_words_in_context(topic_number=123, number_of_documents=20)
#
# Cell In[17], line 6, in display_bolded_topic_words_in_context(topic_number, number_of_documents, custom_words)
#       4 def display_bolded_topic_words_in_context(topic_number=114, number_of_documents=10, custom_words=None):
# ----> 6     for probability, document in lmw.get_top_docs(training_data, topic_distributions, topic_number, n=number_of_documents):
#       8         print(f"✨Topic {topic_number}✨\n\n{topics[topic_number]}\n")
#      10         probability = f"✨✨✨\n\n**{probability}**"
#
# File ~/anaconda3/lib/python3.10/site-packages/little_mallet_wrapper/little_mallet_wrapper.py:193, in get_top_docs(training_data, topic_distributions, topic_index, n)
# ...

# %%
#Topic 124

display_bolded_topic_words_in_context(topic_number=124, number_of_documents=20)
